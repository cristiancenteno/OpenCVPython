# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pwd
# Out:
# 'C:\\Users\\ccenteno\\Documents\\GitHub\\OpenCVPython'

# %%
imagen = Image.open('zorro.png')

# %%
imagen
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=340x551 at 0x1F99087D940>

# %%
type(imagen)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
imagen.size
# Out:
# (340, 551)

# %%
array_imagen = np.asarray(imagen)

# %%
array_imagen
# Out:
# array([[[125, 106,  92, 255],
#         [125, 106,  92, 255],
#         [126, 107,  93, 255],
#         ...,
#         [143, 127, 101, 255],
#         [142, 126, 101, 255],
#         [140, 124,  99, 255]],
#
#        [[126, 107,  93, 255],
#         [126, 107,  93, 255],
#         [127, 108,  94, 255],
#         ...,
#         [144, 128, 103, 255],
#         [142, 126, 101, 255],
#         [141, 125,  99, 255]],
#
#        [[127, 108,  94, 255],
#         [126, 107,  93, 255],
#         [126, 107,  93, 255],
#         ...,
#         [144, 128, 102, 255],
#         [143, 127, 101, 255],
#         [143, 127, 101, 255]],
#
#        ...,
#
#        [[117, 154, 167, 255],
#         [132, 174, 196, 255],
#         [134, 175, 203, 255],
#         ...,
#         [ 73,  74,  73, 255],
#         [ 58,  59,  58, 255],
#         [ 62,  62,  60, 255]],
#
#        [[109, 147, 157, 255],
#         [100, 144, 156, 255],
#         [107, 150, 168, 255],
#         ...,
#         [ 80,  81,  81, 255],
# ...

# %%
plt.imshow(array_imagen)

# %%
array_imagen.shape
# Out:
# (551, 340, 4)

# %%
array_imagen[:,:,0]
# Out:
# array([[125, 125, 126, ..., 143, 142, 140],
#        [126, 126, 127, ..., 144, 142, 141],
#        [127, 126, 126, ..., 144, 143, 143],
#        ...,
#        [117, 132, 134, ...,  73,  58,  62],
#        [109, 100, 107, ...,  80,  71,  76],
#        [ 99,  88, 103, ...,  67,  58,  75]], dtype=uint8)
