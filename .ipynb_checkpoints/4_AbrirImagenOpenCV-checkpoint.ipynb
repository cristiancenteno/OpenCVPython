# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
imagen = cv2.imread('zorro.png')

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
imagen.shape
# Out:
# (551, 340, 3)

# %%
plt.imshow(imagen)

# %%
#openCv BGR
#MatPlotLib RGB

# %%
imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen)

# %%
imagen_b_n = cv2.imread('zorro.png', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_b_n, cmap='gray')
