# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen = cv2.imread('zorro.png')
imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen)

# %%
imagen.shape
# Out:
# (551, 340, 3)

# %%
imagen_2  = cv2.resize(imagen,(600,500)) #x600 y500

# %%
plt.imshow(imagen_2)

# %%
ratio_ancho = 0.5
ratio_alto = 0.5
imagen_3 = cv2.resize(imagen,(0,0,) ,ratio_ancho, ratio_alto)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-f190768901c4> in <module>
#       1 ratio_ancho = 0.5
#       2 ratio_alto = 0.5
# ----> 3 imagen_3 = cv2.resize(imagen,(0,0,) ,ratio_ancho, ratio_alto)
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:4048: error: (-215:Assertion failed) inv_scale_y > 0 in function 'cv::resize'
